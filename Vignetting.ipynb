# %%
from astropy.io import fits
from astropy.utils.data import get_pkg_data_filename
# %matplotlib nbagg
from __future__ import division
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Circle

# %%
image1 = fits.open(r'/Users/caridlin/Documents/GitHub/Guider-test/vignetting/Light_008.fits')
image_data1 = image1[0].data

image2 = fits.open(r'/Users/caridlin/Documents/GitHub/Guider-test/vignetting/Light_009.fits')
image_data2 = image2[0].data

image3 = fits.open(r'/Users/caridlin/Documents/GitHub/Guider-test/vignetting/Light_010.fits')
image_data3 = image3[0].data


image4 = fits.open(r'/Users/caridlin/Documents/GitHub/Guider-test/vignetting/Light_011.fits')
image_data4 = image4[0].data


image5 = fits.open(r'/Users/caridlin/Documents/GitHub/Guider-test/vignetting/Light_012.fits')
image_data5 = image5[0].data


image6 = fits.open(r'/Users/caridlin/Documents/GitHub/Guider-test/vignetting/Light_013.fits')
image_data6 = image6[0].data


image7 = fits.open(r'/Users/caridlin/Documents/GitHub/Guider-test/vignetting/Light_014.fits')
image_data7 = image7[0].data


image8 = fits.open(r'/Users/caridlin/Documents/GitHub/Guider-test/vignetting/Light_015.fits')
image_data8 = image8[0].data

image9 = fits.open(r'/Users/caridlin/Documents/GitHub/Guider-test/vignetting/Light_016.fits')
image_data9 = image9[0].data

image0 = fits.open(r'/Users/caridlin/Documents/GitHub/Guider-test/vignetting/Light_017.fits')
image_data0 = image0[0].data

# %%
image_data = np.mean([image_data1, image_data2, image_data3, image_data4, image_data5, image_data6, image_data7, image_data8, image_data9, image_data0], axis=0)
x = int(0.5 * image_data.shape[1])
y = int(0.5 * image_data.shape[0])

# %%
fig,ax = plt.subplots(1)
ax.set_aspect('equal')
im = ax.imshow(image_data, vmin = 0, vmax = 65535, aspect='equal')
fig.colorbar(im)
plt.title('vignetting')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.pyplot as plt
import numpy as np

Array = image_data
x = int(0.5 * image_data.shape[1])
y = int(0.5 * image_data.shape[0])

fig_mpl, ax = plt.subplots(facecolor = 'white')

line = ax.imshow(Array, aspect='equal')
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size = "5%", pad = 0.05)
caxb = divider.append_axes("bottom", size = "30%", pad = 0.05)
caxl = divider.append_axes("left", size = "20%", pad = 0.05)

bar = fig_mpl.colorbar(line, cax = cax, orientation = 'vertical') 
ax.axhline(y, color = 'red')
ax.axvline(x, color = 'red')      

X = np.linspace(0, 2 * x - 1 , 2 * x)
Y = np.linspace(0, 2 * y - 1 , 2 * y)
projb, = caxb.plot(X, Array[int(x)], color = 'red')
projl, = caxl.plot(Array[:, int(y)], Y, color = 'red')

caxb.set_ylim(-0.1*np.max(Array), 1.1*np.max(Array))
caxb.set_xlim(0, x * 2  - 1)
caxl.set_xlim(-0.1*np.max(Array), 1.1*np.max(Array))
caxl.set_ylim(0, y * 2 - 1)

ax.set_xticks([])
ax.set_yticks([])
caxb.set_xticks([])
caxl.set_yticks([])
caxb.set_yticks([np.min(Array), np.max(Array)])
caxl.set_xticks([np.min(Array), np.max(Array)])
caxb.yaxis.tick_right()

for tick in caxl.get_xticklabels():
    tick.set_rotation(-90)

caxb.grid(color = 'black', marker = 8)
caxl.grid(color = 'black', marker = 8)

fig_mpl.subplots_adjust(wspace = 0)
fig_mpl.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">
