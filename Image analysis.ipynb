# %%
from astropy.io import fits
from astropy.utils.data import get_pkg_data_filename
# %matplotlib nbagg
from __future__ import division
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Circle

# %%
image = fits.open(r'/Users/caridlin/Documents/GitHub/Guider-test/pinhole/pinhole1_1/Light_104.fits')

# %%
image.info()
# Out:
# Filename: /Users/caridlin/Documents/GitHub/Guider-test/pinhole/pinhole1_1/Light_104.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   (3326, 2504)   int16 (rescales to uint16)

# %%
hdr = image[0].header
list(hdr.keys())
# Out:
# ['SIMPLE',
#  'BITPIX',
#  'NAXIS',
#  'NAXIS1',
#  'NAXIS2',
#  'EXTEND',
#  'COMMENT',
#  'COMMENT',
#  'COMMENT',
#  'BZERO',
#  'BSCALE',
#  'XBINNING',
#  'YBINNING',
#  'XPIXSZ',
#  'YPIXSZ',
#  'EXPTIME',
#  'CCD-TEMP',
#  'IMAGETYP',
#  'DATE-OBS',
#  'INSTRUME']

# %%
image_data = image[0].data
x = int(0.5 * image_data.shape[1])
y = int(0.5 * image_data.shape[0])
print(image_data.shape)
print(type(image_data[0,0]))
print((x, y))
print(np.max(image_data))
print(np.min(image_data))
# Out:
# (2504, 3326)
# <type 'numpy.uint16'>
# (1663, 1252)
# 65535
# 1978

# %%
fig,ax = plt.subplots(1)
ax.set_aspect('equal')
image_data1 = image_data
# x1 = 2155
# y1 = 540
# image_data1 = image_data[x1 - 20: x1 + 20, y1 - 20: y1 + 20]
im = ax.imshow(image_data1, vmin = 1000, vmax = 0.2 * 65535, aspect='equal')
fig.colorbar(im)
plt.title('Pinhole 6, 55mm')
# for r_ in range(10, 5000, 50):
#     circ = Circle((x, y), r_, color = 'white', ls = '--', fill = None, alpha = 0.4)
#     ax.add_patch(circ)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig,ax = plt.subplots(1)
ax.set_aspect('equal')
ax.imshow(image_data ** 0.5, vmin = 1.68 * np.min(image_data ** 0.5), vmax = 0.475 * np.max(image_data ** 0.5))
for r_ in range(10, 5000, 50):
    circ = Circle((x, y), r_, color = 'white', ls = '--', fill = None, alpha = 0.6)
    ax.add_patch(circ)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig,ax = plt.subplots(1)
ax.set_aspect('equal')
ax.imshow(image_data, vmin = 2 * np.min(image_data), vmax = 0.3 * np.max(image_data))
for r_ in range(10, 5000, 50):
    circ = Circle((x, y), r_, color = 'white', ls = '--', fill = None, alpha = 0.6)
    ax.add_patch(circ)
# Out:
# <img src="data:image/png;base64,..." width="640">
